# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from bs4 import BeautifulSoup
from unidecode import unidecode
from collections import Counter
from datetime import datetime, timedelta
from team_maker import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
positions = ['C', '1B', '2B', 'SS', '3B', 'OF', 'OF', 'OF', 'P', 'P']

df = pd.read_csv('DKSalaries.csv')
# df['PPK'] = df.AvgPointsPerGame / df.Salary


# eff = pd.concat(baselist)
# eff.AvgPointsPerGame.sum()
# eff.sort_values('AvgPointsPerGame')
# pd.concat(,  ].extend(baselist))

# %%
eff.AvgPointsPerGame.sum()
# Out:
# 105.0

# %%
def get_pitcher_adjustments():
    """
    scrapes data from baseball prospectus and returns a dataframe with a 
    multiplyer for each pitcher based on their WHIP
    """
    rq = requests.get('https://legacy.baseballprospectus.com/sortable/index.php?cid=2508773').content
    souped = BeautifulSoup(rq, 'html.parser')
    ttdata = souped.find('table', {'id' : 'TTdata'})
    hdrs = [x.text for x in ttdata.find('tr').findAll('td')]
    data = []
    for r in ttdata.findAll('tr')[1:]:
        data.append([x.text for x in r.findAll('td')])

    pf = pd.DataFrame(data, columns = hdrs)
    numheaders = list(pf)[3:]
    for header in numheaders:
        pf[header] = pd.to_numeric(pf[header])
    pf = pf[pf['G'] > (pf['G'].mean() - pf["G"].std())]
    pf['WHIP'] = (pf['H'] + pf['BB'] + pf['HBP']) / pf['IP']
    # pf.dtypes
    pf['MULT'] = pf['WHIP'] / pf['WHIP'].mean()
    return pf[['NAME', 'MULT']]    

def get_projected_players():
    """
    Gets projected players from 
    https://rotogrinders.com/lineups/mlb?site=draftkings
    """
    players = []
    
    rq = requests.get('https://rotogrinders.com/lineups/mlb?site=draftkings').content

    souped = BeautifulSoup(rq, 'html.parser')

    divs = souped.findAll('div', {'class' : 'blk game'})
    for div in divs:
        
        hm = div.find('div', {'class' : 'blk home-team'})
        aw = div.find('div', {'class' : 'blk away-team'})

        hp = hm.find('div', {'class' : 'pitcher players'}).find('a', {'class' : 'player-popup'}).text
        ap = aw.find('div', {'class' : 'pitcher players'}).find('a', {'class' : 'player-popup'}).text

        ht = hm.find('ul', {'class' : 'players unconfirmed'})#.findAll('li', {'class' : 'player'})
        at = aw.find('ul', {'class' : 'players unconfirmed'})#.findAll('li', {'class' : 'player'})

        ht = ht.findAll('li', {'class' : 'player'})
        ht = [x.find('span', {'class' : 'pname'}).text.strip() for x in ht]

        at = at.findAll('li', {'class' : 'player'})
        at = [x.find('span', {'class' : 'pname'}).text.strip() for x in at]

        players.extend([hp, ap])
        players.extend(at)
        players.extend(ht)

    return players

def choose_top_players_pos(df, positions):
    """
    df = DataFrame of all available players
    positions = list of strings, positions to be staffed,
                each position should be in the list the number
                of times it is in the roster
                
    returns a dataframe of the top n players for each position, 
    where n is the number of times the position appears in the list
    """
    df = df.set_index(['Roster Position'])
    
    # Getting counter dict of positions
    pos_count = Counter(positions)
    
    # Creating a list of mini dfs with top players by position
    baselist = [df.loc[x][:pos_count[x]] for x in pos_count]
   
    # Making one big dataframe and concatenating
    return pd.concat(baselist)

def choose_top_players_flex(df, num):
    """
    df = DataFrame of all available players
    num = int, number of players to choose
    
    returns a dataframe of the top n players, where n == num
    """
    
    # Removing injured players from the dataframe
    inj = get_injured_players('baseball')
    df = df[~df['Name'].isin(inj)]
    
    # Returning top players
    return df[:num]

def get_injured_players(sport):
    """
    sport = str, the targeted sport
    """
    
    # Dict of pages for injury reports
    urls = {
        'baseball' : 'https://scores.nbcsports.com/mlb/stats.asp?file=inj'
    }
    url = urls[sport]
    
    # Getting html of injury report page
    rq = requests.get(url)
    souped = BeautifulSoup(rq.content, 'html.parser')
    tds = souped.find_all('td')
    
    # Creating list of injured players
    inj = []
    for n in range(5, len(tds), 3):
        
        td = tds[n].getText()
        if ',' in td:
            
            # Matching source unicode formatting
            td = unidecode(td.split(',')[0])
            
            inj.append(td)

    return inj
    

def make_efficient_team(df, positions = None, num = None):
    """
    df = DataFrame of all available players
    positions = list of strings
    num = int
    
    Returns a dataframe of a team with the best ratio of 
    average points to cost.
    """
    df = df.sort_values('PPK', ascending=False)
    
    if positions != None: 
        return choose_top_players_pos(df, positions)
    if num != None:
        return choose_top_players_flex(df, num)
        

def make_best_team(df, positions = None, num = None):
    """
    df = DataFrame of all available players
    positions = list of strings
    num = int
    
    Returns a dataframe of a team with the best average points.
    """

    df = df.sort_values('AvgPointsPerGame', ascending=False)
    
    if positions != None: 
        return choose_top_players_pos(df, positions)
    if num != None:
        return choose_top_players_flex(df, num)
    
def make_team_w_pos(positions):
    """
    positions = list of strings, positions to be staffed,
                each position should be in the list the number
                of times it is in the roster
    
    returns a dataframe of a team formed with the efficient to
    best method. Starts with the most efficient players for 
    their price, then adds the best players, regardless of price, 
    while keeping the whole team's price under the cap
    """
   
    df = prep_dataframe()
    
    eff = make_efficient_team(df, positions = positions)
    best = make_best_team(df, positions = positions)
    
    # 'DEFICIT' = The expectation of best - efficient player
    eff['DEFICIT'] = best.AvgPointsPerGame - eff.AvgPointsPerGame
    best['DEFICIT'] = best.AvgPointsPerGame - eff.AvgPointsPerGame
    
    eff = eff.sort_values('DEFICIT', ascending=False).reset_index() 
    best = best.sort_values('DEFICIT', ascending=False).reset_index()
    
    # Replacing efficient players with best players in deficit order
    for i, e in eff.iterrows():

        ctotal = eff.Salary.sum()
        ctminus = ctotal - e.Salary

        if ctminus + best.Salary.loc[i] <= 50000:
            if best.Name.loc[i] not in eff.Name.unique():
                eff.loc[i] = best.loc[i]
            
    print('Salary:', eff.Salary.sum())
    print('Avg Points:', eff.AvgPointsPerGame.sum())
    print('Avg w/o cap:', best.AvgPointsPerGame.sum())
    print('Sal w/o cap:', best.Salary.sum())
    
    return eff

def make_team_flex(num):
    """
    num = int, number of players to include on the final roster
    
    returns a dataframe of a team formed with the efficient to
    best method. Starts with the most efficient players for 
    their price, then adds the best players, regardless of price, 
    while keeping the whole team's price under the cap
    """
    
    df = prep_dataframe()
    
    # num quadrupled for 'best' to give more options
    eff = make_efficient_team(df, num =num).reset_index()
    best = make_best_team(df, num = num*4).reset_index()
    
    # 'DEFICIT' = The expectation of best - efficient player
    eff['DEFICIT'] = best.AvgPointsPerGame - eff.AvgPointsPerGame
    best['DEFICIT'] = best.AvgPointsPerGame - eff.AvgPointsPerGame
    
    eff = eff.sort_values('DEFICIT', ascending=False).reset_index() 
    best = best.sort_values('AvgPointsPerGame', ascending=False).reset_index()
    
    # Replacing efficient players one at a time while staying under cap
    for i, e in eff.iterrows():
        
        for j, r in best.iterrows():
            
            ctotal = eff.Salary.sum()
            ctminus = ctotal - e.Salary

            if ctminus + best.Salary.loc[j] <= 50000 \
            and best.Name.loc[j] not in eff.Name.unique()\
            and e.AvgPointsPerGame < r.AvgPointsPerGame:
                
                eff.loc[i] = best.loc[j]
                break
            
    print('Salary:', eff.Salary.sum())
    print('Avg Points:', eff.AvgPointsPerGame.sum())
    print('Avg w/o cap:', best.AvgPointsPerGame[:num].sum())
    print('Sal w/o cap:', best.Salary[:num].sum())
    
    return eff, best

def prep_dataframe():
    """
    Builds a dataframe from DKSalaries.csv and prepares it
    for use by other functions
    """
    df = pd.read_csv('DKSalaries.csv')
    
    # Adding opposing team info
    all_matchups = []
    for x in df['Game Info']:
        ats = x.split('@')
        t1 = ats[0]
        t2 = ats[1].split(' ')[0]
        all_matchups.append([t1, t2])

    OpposingTeam = []
    for mu, ta in zip(all_matchups, df.TeamAbbrev):
        if mu[0] == ta:
            OpposingTeam.append(mu[1])
        else:
            OpposingTeam.append(mu[0])

    df['OpposingTeam'] = OpposingTeam


    df['PPK'] = df.AvgPointsPerGame / df.Salary * 1000
#     inj = get_injured_players('baseball')
#     df = df[~df['Name'].isin(inj)]
#     df = clear_dead_weight(df.set_index('Roster Position'))
    act = get_projected_players()
    df = df[df['Name'].isin(act)]
    
    return df#.reset_index()

def clear_dead_weight(df):
    
    df = df.sort_values('PPK', ascending=False)
    output = pd.DataFrame()
    
    for pos in [x for x in df.index.unique() if len(x) < 3]:
        print(pos)
        tdf = df.loc[pos]
#         return tdf
        floor = tdf.AvgPointsPerGame.iloc[0]
        tdf = tdf[tdf['AvgPointsPerGame'] >= floor]
#         tdf['Roster Position'] = pos

        output = pd.concat([output, tdf])
    
#     output = output.set_index('Roster Position')
    return output

def create_active_player_filter():
    """
    Gets lineups from news sites and returns a list of players who are
    playing tonight.
    """
    rq = requests.get('https://www.mlb.com/starting-lineups').content
    souped = BeautifulSoup(rq, 'html.parser')

    divs = souped.findAll("div", {"class": "starting-lineups__matchup"})

    avails = pd.DataFrame()
    all_sps = []

    for div in divs:
        htm = div.find("span", {"class": "starting-lineups__team-name starting-lineups__team-name--home"}).text.strip()
        atm = div.find("span", {"class": "starting-lineups__team-name starting-lineups__team-name--away"}).text.strip()

        htmlu = div.find("ol", {"class": "starting-lineups__team starting-lineups__team--home"})
        atmlu = div.find("ol", {"class": "starting-lineups__team starting-lineups__team--away"})

        htmbs = htmlu.findAll("li", {"class": "starting-lineups__player"})
        atmbs = atmlu.findAll("li", {"class": "starting-lineups__player"})

        sps = div.findAll("div", {"class" : "starting-lineups__pitcher-name"})
        all_sps.extend([x.text.strip() for x in sps])

        htmbs = pd.DataFrame([x.text.split(' ') for x in htmbs])
        htmbs[4] = htm
        atmbs = pd.DataFrame([x.text.split(' ') for x in atmbs])
        atmbs[4] = atm

        avails = pd.concat([avails, htmbs, atmbs])

    avails.columns=['fname', 'lname', 'b', 'pos', 'team']

    avails['name'] = avails.fname + ' ' + avails.lname

    avails = avails[['name', 'b', 'pos', 'team']]

    anames = []

    for i, x in avails.iterrows():
        if x['b'] == 'Jr.':
            anames.append(x['name'] + ' ' +  x['b'])  
        else:
            anames.append(x['name'])

    return all_sps + anames

def make_team_w_pos_ratchet(positions, method = 'points', df = None):
    """
    positions = list of strings, positions to be staffed,
                each position should be in the list the number
                of times it is in the roster
    
    returns a dataframe of a team formed with the efficient to
    best method. Starts with the most efficient players for 
    their price, then adds the best players, regardless of price, 
    while keeping the whole team's price under the cap
    """
    
    if df == None:
        df = prep_dataframe()
        
    df = df.sort_values('AvgPointsPerGame', ascending=False)
    
    best = make_best_team(df, positions = positions)
    
    swaps = 0
    
    while best.Salary.sum() > 50000:
        
        over = best.Salary.sum() - 50000
        
        swaps += 1
        print('swaps:', swaps)
        rmdf = df[~df['Name'].isin(best.Name)]
        
        loss = []
        alts = []
        diffs = []
        for i, r in best.iterrows():
            
            tdf = rmdf[rmdf['Position'] == r['Position']]
            tdf = tdf[tdf['Salary'] < r['Salary']]
            
            if len(tdf) > 0:
                ns, na = tdf.iloc[0][['Salary', 'AvgPointsPerGame']]
                os, oa = r[['Salary', 'AvgPointsPerGame']]
                alts.append(tdf.iloc[0])

    #             return ns, np, os, op

#                 ls = (os - ns) / (oa - na)
                if method == 'points':
                    ls = oa - na
                    
                if method == 'ratio':
                    ls = (oa - na) / (os - ns)
                
                diffs.append([os - ns])
                loss.append(ls)
            else:
                loss.append(10000.5)
                alts.append(None)
                diffs.append([os])
        
#         if any([x <= over] for x in)
#         loss = np.array(loss)
#         for i in range(len(diffs)):
#             if diffs[i] > over:
#                 loss[i] = max(loss)
        rep = np.array(loss).argmin()
        best.iloc[rep] = alts[rep]
    
    
            
#     print('Salary:', eff.Salary.sum())
#     print('Avg Points:', eff.AvgPointsPerGame.sum())
    print('Avg points:', best.AvgPointsPerGame.sum())
    print('Salary:', best.Salary.sum())
    
    return best

# %%
positions = ['C', '1B', '2B', 'SS', '3B', 'OF', 'OF', 'OF', 'P', 'P']

# df = pd.read_csv('DKSalaries.csv')
# df['PPK'] = df.AvgPointsPerGame / df.Salary

# # df = df[~df['Name'].isin(['Yoenis Cespedes', 'Robinson Cano'])]

# eff = make_efficient_team(df)

# best = make_best_team(df)

# eff['DEFICIT'] = best.AvgPointsPerGame - eff.AvgPointsPerGame
# best['DEFICIT'] = best.AvgPointsPerGame - eff.AvgPointsPerGame

# eff = eff.sort_values('DEFICIT', ascending=False).reset_index() 
# best = best.sort_values('DEFICIT', ascending=False).reset_index()

# for i, e in eff.iterrows():
    
#     ctotal = eff.Salary.sum()
#     ctminus = ctotal - e.Salary
    
#     if ctminus + best.Salary.loc[i] <= 50000:
#         eff.loc[i] = best.loc[i]
        


# eff.AvgPointsPerGame.sum()

# make_team_w_pos(df, positions)
# eff, best = make_team_flex(df, 6)

# eff['DEFICIT'] = best.AvgPointsPerGame - eff.AvgPointsPerGame
# eff

# # loss = 
# make_team
# make_team_w_pos_ratchet(positions)
# make_team_w_pos(positions)
df = make_team_w_pos_ratchet(positions, method = 'ratio')
export_team(df)
# df
# max([3,5,6])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-b02c5311ea1c> in <module>()
#      38 # make_team_w_pos_ratchet(positions)
#      39 # make_team_w_pos(positions)
# ---> 40 df = make_team_w_pos_ratchet(positions, method = 'ratio')
#      41 export_team(df)
#      42 # df
#
# ~\DraftKings\team_maker.py in make_team_w_pos_ratchet(positions, method, df, column)
#     457         df = prep_dataframe()
#     458
# --> 459     df = df.sort_values(column, ascending=False)
#     460
#     461     best = make_best_team(df, positions = positions)
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
# var = []
# tdf = df.loc['P'].sort_values('AvgPointsPerGame', ascending=False)

# for i in range(len(tdf[:15]) - 1):
#     apg,salary = tdf.iloc[i][['AvgPointsPerGame', 'Salary']]
#     apg1,salary1 = tdf.iloc[i+1][['AvgPointsPerGame', 'Salary']]
#     div = salary - salary1 / 100
#     loss = (apg - apg1) / ((salary - salary1) / 100)

#     var.append(loss)
# var

make_team_w_pos_ratchet(positions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0e5ae0623a4f> in <module>()
#      11 # var
#      12
# ---> 13 make_team_w_pos_ratchet(positions)
#
# NameError: name 'positions' is not defined

# %%
# 13 * 15 * 1 * 1 * 16 * 7 * 15
# df.loc[df.index.unique()[5:]]
tdf
# df[((df['Position'] == 'OF') & (df['Salary'] <= 6000))]
# df.set_index('Roster Position', inplace=True)
# df.loc["P"]
# Out:
#                 Position                       Name + ID                 Name  \
# Roster Position
# P                     SP           Chris Sale (11020015)           Chris Sale
# P                     SP          Gerrit Cole (11020018)          Gerrit Cole
# P                     SP         Max Scherzer (11020017)         Max Scherzer
# P                     SP     Justin Verlander (11019167)     Justin Verlander
# P                     SP         Trevor Bauer (11020016)         Trevor Bauer
# P                     SP         Jacob deGrom (11019168)         Jacob deGrom
# P                     SP         Tommy Milone (11020427)         Tommy Milone
# P                     SP         James Paxton (11020034)         James Paxton
# P                     SP        Luis Severino (11019172)        Luis Severino
# P                     SP       Charlie Morton (11020025)       Charlie Morton
# P                     SP           Aaron Nola (11020043)           Aaron Nola
# P                     SP          Blake Snell (11020042)          Blake Snell
# P                     SP         Corey Kluber (11020019)         Corey Kluber
# P                     SP       Patrick Corbin (11019169)       Patrick Corbin
# P                     SP         Zack Greinke (11020024)         Zack Greinke
# P                     SP    Stephen Strasburg (11020020)    Stephen Strasburg
# P                     SP      Carlos Carrasco (11020022)      Carlos Carrasco
# P                     SP         Jose Berrios (11020026)         Jose Berrios
# P                     SP       Freddy Peralta (11020053)       Freddy Peralta
# P                     SP     Mike Foltynewicz (11020028)     Mike Foltynewicz
# P                     SP     Noah Syndergaard (11020027)     Noah Syndergaard
# P                     SP       Mike Clevinger (11019171)       Mike Clevinger
# P                     SP      Masahiro Tanaka (11020029)      Masahiro Tanaka
# P                     SP            J.A. Happ (11020039)            J.A. Happ
# P                11020310    4100  DET@OAK 08/03/2018 10:05PM ET        DET
# P                11020287    4300  BAL@TEX 08/03/2018 08:05PM ET        TEX
# P                11020188    5200   CWS@TB 08/03/2018 07:10PM ET        CWS
# P                11020272    4400   SF@ARI 08/03/2018 09:40PM ET        ARI
# P                11020300    4200  CIN@WAS 08/03/2018 07:05PM ET        WAS
# P                11020614    4000   KC@MIN 08/03/2018 08:10PM ET        MIN
# P                11020224    4900  LAA@CLE 08/03/2018 07:10PM ET        LAA
#
#                  AvgPointsPerGame       PPK
# Roster Position
# P                           28.68  2.124444
# P                           26.57  2.075781
# P                           26.43  2.033077
# P                           26.18  1.998473
# P                           25.50  1.917293
# P                           24.73  1.994355
# P                           23.20  5.800000
# P                           22.87  2.382292
# P                           22.86  2.484783
# P                           22.51  2.027928
# P                           22.40  2.488889
# P                           22.35  2.483333
# P                           22.09  1.840833
# P                           22.00  2.115385
# P                           21.03  1.877679
# P                           20.20  1.683333
# P                           20.16  1.768421
# P                           20.03  1.854630
# P                           19.79  2.328235
# P                           19.68  1.874286
# P                           18.95  1.771028
# P                           18.93  2.035484
# P                           18.44  1.790291
# P                           18.30  1.989130
# P                           18.18  1.567241
# P                           18.03  1.767647
# P                           17.91  2.058621
# P                           17.74  1.847917
# P                           17.65  1.819588
# P                           17.57  1.554867
# ...                           ...       ...
# P                            0.00  0.000000
# P                            0.00  0.000000
# P                            0.00  0.000000
# P                            0.00  0.000000
# P                            0.00  0.000000
# P                            0.00  0.000000
# P                            0.00  0.000000
# P                            0.00  0.000000
# P                            0.00  0.000000
# P                           -0.04 -0.010000
# P                           -0.05 -0.008475
# P                           -0.17 -0.042500
# P                           -0.28 -0.057143
# P                           -0.30 -0.075000
# P                           -0.36 -0.090000
# P                           -0.45 -0.112500
# P                           -0.51 -0.127500
# P                           -1.02 -0.255000
# P                           -1.23 -0.273333
# P                           -1.50 -0.375000
# P                           -2.58 -0.645000
# P                           -2.59 -0.488679
# P                           -3.15 -0.787500
# P                           -3.51 -0.856098
# P                           -3.88 -0.902326
# P                           -4.75 -0.913462
# P                           -4.80 -1.090909
# P                           -5.45 -1.297619
# P                           -6.45 -1.612500
# P                          -12.45 -2.540816
#
# [737 rows x 9 columns]

# %%
eff.Salary.sum()
# Out:
# 49800

# %%
best.AvgPointsPerGame.sum()
# Out:
# 143.88

# %%
# Out:
# ['Jake Lamb',
#  'Shelby Miller',
#  'Jarrod Dyson',
#  'Deven Marrero',
#  'Taijuan Walker',
#  'Sam Freeman',
#  'Peter Moylan',
#  'Arodys Vizcaíno',
#  'Brandon McCarthy',
#  "Darren O'Day",
#  'Mike Soroka',
#  'José Ramírez',
#  'Jacob Lindgren',
#  'Grant Dayton',
#  'Steve Wilkerson',
#  'Craig Gentry',
#  'Richard Bleier',
#  'Pedro Araujo',
#  'Gabriel Ynoa',
#  'Rafael Devers',
#  'Chris Sale',
#  'Eduardo Rodriguez',
#  'Christian Vázquez',
#  'Steven Wright',
#  'Dustin Pedroia',
#  'Carson Smith',
#  'Marco Hernández',
#  'Austin Maddox',
#  'Kris Bryant',
#  'Anthony Bass',
#  'Brandon Morrow',
#  'Justin Hancock',
#  'Yu Darvish',
#  'Drew Smyly',
#  'Nate Jones',
#  'Danny Farquhar',
#  'Miguel González',
#  'Jesse Winker',
#  'Jackson Stephens',
#  'Alex Blandino',
#  'Scott Schebler',
#  'Rookie Davis',
#  'Tyler Naquin',
#  'Josh Tomlin',
#  'Lonnie Chisenhall',
#  'Evan Marshall',
#  'Andrew Miller',
#  'Nick Goody',
#  'Danny Salazar',
#  'Cody Anderson',
#  'Chris Rusin',
#  'Mike Dunn',
#  'Chad Bettis',
#  'Rayan González',
#  'Michael Fulmer',
#  'Miguel Cabrera',
#  'Daniel Norris',
#  'Jose Altuve',
#  'Brian McCann',
#  'Carlos Correa',
#  'Jandel Gustave',
#  'Brian Goodwin',
#  'Ian Kennedy',
#  'Jorge Soler',
#  'Blaine Boyer',
#  'Eric Skoglund',
#  'Cheslor Cuthbert',
#  'Nate Karns',
#  'Jesse Hahn',
#  'Garrett Richards',
#  'Chris Young',
#  'Jake Jewell',
#  'John Lamb',
#  'Zack Cozart',
#  'René Rivera',
#  'Keynan Middleton',
#  'Blake Wood',
#  'JC Ramírez',
#  'Matt Shoemaker',
#  'Alex Meyer',
#  'Chase Utley',
#  'Ross Stripling',
#  'Zac Rosscup',
#  'Yimi García',
#  'Josh Fields',
#  'Tony Cingrani',
#  'Dennis Santana',
#  'Hyun-Jin Ryu',
#  'Corey Seager',
#  'Tom Koehler',
#  'Julio Urías',
#  'Garrett Cooper',
#  'Drew Rucinski',
#  'Lewis Brinson',
#  'Sandy Alcantara',
#  'Caleb Smith',
#  "Chris O'Grady",
#  'Brent Suter',
#  'Zach Davies',
#  'Nick Franklin',
#  'Jimmy Nelson',
#  'Stephen Vogt',
#  'Aaron Slegers',
#  'Jason Castro',
#  'Michael Pineda',
#  'Phillip Evans',
#  'Yoenis Céspedes',
#  'Jay Bruce',
#  'AJ Ramos',
#  'Juan Lagares',
#  "Travis d'Arnaud",
#  'Rafael Montero',
#  'David Wright',
#  'T.J. Rivera',
#  'J.A. Happ',
#  'Aaron Judge',
#  'Gary Sánchez',
#  'Clint Frazier',
#  'Jordan Montgomery',
#  'Jacoby Ellsbury',
#  'Ben Heller',
#  'Chad Pinder',
#  'Paul Blackburn',
#  'Matt Joyce',
#  'Daniel Gossett',
#  'Andrew Triggs',
#  'Jharel Cotton',
#  'Wilson Ramos',
#  'J.P. Crawford',
#  'Pedro Florimón',
#  'Jerad Eickhoff',
#  'Josh Bell',
#  'Corey Dickerson',
#  'Nik Turley',
#  'Chad Kuhl',
#  'A.J. Schugel',
#  'Nick Burdi',
#  'Eric Lauer',
#  'Luis Perdomo',
#  'Colten Brewer',
#  'Bryan Mitchell',
#  'Franchy Cordero',
#  'Alex Dickerson',
#  'Dinelson Lamet',
#  'Pablo Sandoval',
#  'Johnny Cueto',
#  'Brandon Belt',
#  'Jeff Samardzija',
#  'Hunter Strickland',
#  'Julian Fernández',
#  'Roenis Elías',
#  'Dan Altavilla',
#  'Robinson Canó',
#  'Erasmo Ramírez',
#  'David Phelps',
#  'Carlos Martínez',
#  'Luke Gregerson',
#  'Brett Cecil',
#  'Kolten Wong',
#  'Michael Wacha',
#  'Alex Reyes',
#  'Adam Wainwright',
#  'Dominic Leone',
#  'Blake Snell',
#  'Chaz Roe',
#  'Vidal Nuño',
#  'Wilmer Font',
#  'José De León',
#  'Ryan Rua',
#  'Nomar Mazara',
#  'Tony Barnette',
#  'Matt Bush',
#  'Doug Fister',
#  'Ronald Herrera',
#  'Clayton Blackburn',
#  'Lourdes Gurriel Jr.',
#  'Kevin Pillar',
#  'Rhiner Cruz',
#  'Aaron Sanchez',
#  'Josh Donaldson',
#  'Troy Tulowitzki',
#  'Stephen Strasburg',
#  'Sean Doolittle',
#  'Erick Fedde',
#  'Howie Kendrick',
#  'Jhonatan Solano',
#  'Joaquin Benoit',
#  'Joe Ross']

# %%
# Out:
# ['Homer Bailey',
#  'Noah Syndergaard',
#  'Kyle Gibson',
#  'Trevor Bauer',
#  'Luke Weaver',
#  'Wei-Yin Chen',
#  'Wade LeBlanc',
#  'Martin Perez',
#  'Lance Lynn',
#  'Dylan Covey',
#  'Cole Hamels',
#  'Jakob Junis',
#  'Joe Musgrove',
#  'Kyle Freeland',
#  'Jake Arrieta',
#  'Zack Godley',
#  'Matthew Boyd',
#  'Nick Tropeano',
#  'Charlie Morton',
#  'Dereck Rodriguez',
#  'Amed Rosario',
#  'Jeff McNeil',
#  'Wilmer Flores',
#  'Michael Conforto',
#  'Todd Frazier',
#  'Brandon Nimmo',
#  'Austin Jackson',
#  'Kevin Plawecki',
#  'Noah Syndergaard',
#  'Jose Peraza',
#  'Joey Votto',
#  'Scooter Gennett',
#  'Eugenio Suarez',
#  'Mason Williams',
#  'Tucker Barnhart',
#  'Preston Tucker',
#  'Homer Bailey',
#  'Billy Hamilton',
#  'Francisco Lindor',
#  'Michael Brantley',
#  'Jose Ramirez',
#  'Edwin Encarnacion',
#  'Yonder Alonso',
#  'Leonys Martin',
#  'Jason Kipnis',
#  'Roberto Perez',
#  'Brandon Guyer',
#  'Joe Mauer',
#  'Eddie Rosario',
#  'Jorge Polanco',
#  'Logan Morrison',
#  'Miguel Sano',
#  'Max Kepler',
#  'Logan Forsythe',
#  'Jake Cave',
#  'Bobby Wilson',
#  'Derek Dietrich',
#  'Brian Anderson',
#  'J.T. Realmuto',
#  'Justin Bour',
#  'Starlin Castro',
#  'Martin Prado',
#  'JT Riddle',
#  'Magneuris Sierra',
#  'Wei-Yin Chen',
#  'Matt Carpenter',
#  'Yadier Molina',
#  'Jose Martinez',
#  'Marcell Ozuna',
#  'Jedd Gyorko',
#  'Paul DeJong',
#  'Harrison Bader',
#  'Yairo Munoz',
#  'Luke Weaver',
#  'Shin-Soo Choo',
#  'Rougned Odor',
#  'Elvis Andrus',
#  'Adrian Beltre',
#  'Jurickson Profar',
#  'Robinson Chirinos',
#  'Joey Gallo',
#  'Isiah Kiner-Falefa',
#  'Carlos Tocci',
#  'Dee Gordon',
#  'Jean Segura',
#  'Mitch Haniger',
#  'Nelson Cruz',
#  'Kyle Seager',
#  'Ryon Healy',
#  'Cameron Maybin',
#  'Mike Zunino',
#  'Guillermo Heredia',
#  'Yoan Moncada',
#  'Yolmer Sanchez',
#  'Jose Abreu',
#  'Daniel Palka',
#  'Avisail Garcia',
#  'Nicky Delmonico',
#  'Tim Anderson',
#  'Kevan Smith',
#  'Adam Engel',
#  'Brett Gardner',
#  'Giancarlo Stanton',
#  'Didi Gregorius',
#  'Aaron Hicks',
#  'Gleyber Torres',
#  'Greg Bird',
#  'Miguel Andujar',
#  'Neil Walker',
#  'Kyle Higashioka',
#  'Whit Merrifield',
#  'Alex Gordon',
#  'Salvador Perez',
#  'Hunter Dozier',
#  'Rosell Herrera',
#  'Jorge Bonifacio',
#  'Adalberto Mondesi',
#  'Alcides Escobar',
#  'Drew Butera',
#  'Anthony Rizzo',
#  'Ben Zobrist',
#  'Jason Heyward',
#  'Javier Baez',
#  'Kyle Schwarber',
#  'Willson Contreras',
#  'Ian Happ',
#  'Addison Russell',
#  'Albert Almora Jr.',
#  'David Dahl',
#  'DJ LeMahieu',
#  'Carlos Gonzalez',
#  'Nolan Arenado',
#  'Trevor Story',
#  'Gerardo Parra',
#  'Ian Desmond',
#  'Chris Iannetta',
#  'Kyle Freeland',
#  'Jon Jay',
#  'Paul Goldschmidt',
#  'David Peralta',
#  'Eduardo Escobar',
#  'Steven Souza Jr.',
#  'Daniel Descalso',
#  'Nick Ahmed',
#  'Alex Avila',
#  'Zack Godley']

# %%
# datetime.today() - timedelta(5)
avails.pos.unique()
# Out:
# array(['SS', '2B', '1B', 'LF', '3B', 'RF', 'CF', 'C', 'P', 'DH', '(R)'],
#       dtype=object)

# %%
for i, x in avails.iterrows():
    if x['b'] == 'Jr.':
        print(x['name'] + ' ' +  x['b'])  
    else:
        print(x['name'])
# Out:
# Amed Rosario
# Jeff McNeil
# Wilmer Flores
# Michael Conforto
# Todd Frazier
# Brandon Nimmo
# Austin Jackson
# Kevin Plawecki
# Noah Syndergaard
# Jose Peraza
# Joey Votto
# Scooter Gennett
# Eugenio Suarez
# Mason Williams
# Tucker Barnhart
# Preston Tucker
# Homer Bailey
# Billy Hamilton
# Francisco Lindor
# Michael Brantley
# Jose Ramirez
# Edwin Encarnacion
# Yonder Alonso
# Leonys Martin
# Jason Kipnis
# Roberto Perez
# Brandon Guyer
# Joe Mauer
# Eddie Rosario
# Jorge Polanco
# Logan Morrison
# Miguel Sano
# Max Kepler
# Logan Forsythe
# Jake Cave
# Bobby Wilson
# Derek Dietrich
# Brian Anderson
# J.T. Realmuto
# Justin Bour
# Starlin Castro
# Martin Prado
# JT Riddle
# Magneuris Sierra
# Wei-Yin Chen
# Matt Carpenter
# Yadier Molina
# Jose Martinez
# Marcell Ozuna
# Jedd Gyorko
# Paul DeJong
# Harrison Bader
# Yairo Munoz
# Luke Weaver
# Shin-Soo Choo
# Rougned Odor
# Elvis Andrus
# Adrian Beltre
# Jurickson Profar
# Robinson Chirinos
# Joey Gallo
# Isiah Kiner-Falefa
# Carlos Tocci
# Dee Gordon
# Jean Segura
# Mitch Haniger
# Nelson Cruz
# Kyle Seager
# Ryon Healy
# Cameron Maybin
# Mike Zunino
# Guillermo Heredia
# Yoan Moncada
# Yolmer Sanchez
# Jose Abreu
# Daniel Palka
# Avisail Garcia
# Nicky Delmonico
# Tim Anderson
# Kevan Smith
# Adam Engel
# Brett Gardner
# Giancarlo Stanton
# Didi Gregorius
# Aaron Hicks
# Gleyber Torres
# Greg Bird
# Miguel Andujar
# Neil Walker
# Kyle Higashioka
# Whit Merrifield
# Alex Gordon
# Salvador Perez
# Hunter Dozier
# Rosell Herrera
# Jorge Bonifacio
# Adalberto Mondesi
# Alcides Escobar
# Drew Butera
# Anthony Rizzo
# Ben Zobrist
# Jason Heyward
# Javier Baez
# Kyle Schwarber
# Willson Contreras
# Ian Happ
# Addison Russell
# Albert Almora Jr.
# David Dahl
# DJ LeMahieu
# Carlos Gonzalez
# Nolan Arenado
# Trevor Story
# Gerardo Parra
# Ian Desmond
# Chris Iannetta
# Kyle Freeland
# Jon Jay
# Paul Goldschmidt
# David Peralta
# Eduardo Escobar
# Steven Souza Jr.
# Daniel Descalso
# Nick Ahmed
# Alex Avila
# Zack Godley

# %%
players = []
# rq = requests.get('https://rotogrinders.com/lineups/mlb?site=draftkings').content
souped = BeautifulSoup(rq, 'html.parser')
# ("span", {"class": "starting-lineups__team-name starting-lineups__team-name--home"})
divs = souped.findAll('div', {'class' : 'blk game'})
for div in divs:
    hm = div.find('div', {'class' : 'blk home-team'})
    aw = div.find('div', {'class' : 'blk away-team'})
    
    hp = hm.find('div', {'class' : 'pitcher players'}).find('a', {'class' : 'player-popup'}).text
    ap = aw.find('div', {'class' : 'pitcher players'}).find('a', {'class' : 'player-popup'}).text
    
    ht = hm.find('ul', {'class' : 'players unconfirmed'})#.findAll('li', {'class' : 'player'})
    at = aw.find('ul', {'class' : 'players unconfirmed'})#.findAll('li', {'class' : 'player'})
    
    ht = ht.findAll('li', {'class' : 'player'})
    ht = [x.find('span', {'class' : 'pname'}).text.strip() for x in ht]
    
    at = at.findAll('li', {'class' : 'player'})
    at = [x.find('span', {'class' : 'pname'}).text.strip() for x in at]
    
    players.extend([hp, ap])
    players.extend(at)
    players.extend(ht)
    
#     print(hp, ap)

players
# Out:
# ['Gio Gonzalez',
#  'Anibal Sanchez',
#  'Ronald Acuna',
#  'Ozzie Albies',
#  'Freddie Freeman',
#  'Nick Markakis',
#  'Kurt Suzuki',
#  'Adam Duvall',
#  'Johan Camargo',
#  'Dansby Swanson',
#  'Anibal Sanchez',
#  'Adam Eaton',
#  'Trea Turner',
#  'Anthony Rendon',
#  'Bryce Harper',
#  'Juan Soto',
#  'Matt Adams',
#  'Daniel Murphy',
#  'Matt Wieters',
#  'Gio Gonzalez',
#  'Corey Kluber',
#  'Jose Berrios',
#  'Joe Mauer',
#  'Eddie Rosario',
#  'Jorge Polanco',
#  'Miguel Sano',
#  'Max Kepler',
#  'Logan Forsythe',
#  'Logan Morrison',
#  'Bobby Wilson',
#  'Jake Cave',
#  'Francisco Lindor',
#  'Michael Brantley',
#  'Jose Ramirez',
#  'Edwin Encarnacion',
#  'Yonder Alonso',
#  'Melky Cabrera',
#  'Jason Kipnis',
#  'Yan Gomes',
#  'Leonys Martin',
#  'Junior Guerra',
#  'Robbie Erlin',
#  'Manuel Margot',
#  'Eric Hosmer',
#  'Hunter Renfroe',
#  'Christian Villanueva',
#  'Austin Hedges',
#  'Freddy Galvis',
#  'Franmil Reyes',
#  'Cory Spangenberg',
#  'Robbie Erlin',
#  'Lorenzo Cain',
#  'Christian Yelich',
#  'Jesus Aguilar',
#  'Jonathan Schoop',
#  'Ryan Braun',
#  'Travis Shaw',
#  'Erik Kratz',
#  'Orlando Arcia',
#  'Junior Guerra',
#  'J.A. Happ',
#  'Ariel Jurado',
#  'Shin-Soo Choo',
#  'Rougned Odor',
#  'Elvis Andrus',
#  'Adrian Beltre',
#  'Jurickson Profar',
#  'Joey Gallo',
#  'Robinson Chirinos',
#  'Willie Calhoun',
#  'Carlos Tocci',
#  'Brett Gardner',
#  'Giancarlo Stanton',
#  'Didi Gregorius',
#  'Aaron Hicks',
#  'Gleyber Torres',
#  'Gregory Bird',
#  'Miguel Andujar',
#  'Austin Romine',
#  'Neil Walker',
#  'Ryan Borucki',
#  'Rick Porcello',
#  'Mookie Betts',
#  'Andrew Benintendi',
#  'Steve Pearce',
#  'J.D. Martinez',
#  'Xander Bogaerts',
#  'Eduardo Nunez',
#  'Rafael Devers',
#  'Sandy Leon',
#  'Jackie Bradley',
#  'Curtis Granderson',
#  'Devon Travis',
#  'Justin Smoak',
#  'Kendrys Morales',
#  'Yangervis Solarte',
#  'Teoscar Hernandez',
#  'Russell Martin',
#  'Aledmys Diaz',
#  'Kevin Pillar',
#  'Hunter Wood',
#  'David Hess',
#  'Jonathan Villar',
#  'Tim Beckham',
#  'Adam Jones',
#  'Mark Trumbo',
#  'Chris Davis',
#  'Trey Mancini',
#  'Renato Nunez',
#  'Jace Peterson',
#  'Caleb Joseph',
#  'Mallex Smith',
#  'Matt Duffy',
#  'Jakob Bauers',
#  'C.J. Cron',
#  'Joseph Wendle',
#  'Kevin Kiermaier',
#  'Brandon Lowe',
#  'Michael Perez',
#  'Willy Adames',
#  'Justin Verlander',
#  'James Paxton',
#  'Dee Gordon',
#  'Jean Segura',
#  'Mitch Haniger',
#  'Nelson Cruz',
#  'Kyle Seager',
#  'Denard Span',
#  'Ryon Healy',
#  'Mike Zunino',
#  'Cameron Maybin',
#  'Alex Bregman',
#  'Carlos Correa',
#  'Marwin Gonzalez',
#  'Yulieski Gurriel',
#  'Tyler White',
#  'Josh Reddick',
#  'Martin Maldonado',
#  'J.D. Davis',
#  'Jake Marisnick',
#  'Tyler Anderson',
#  'Ross Stripling',
#  'Brian Dozier',
#  'Manny Machado',
#  'Justin Turner',
#  'Enrique Hernandez',
#  'Matt Kemp',
#  'Yasiel Puig',
#  'Chris Taylor',
#  'Austin Barnes',
#  'Ross Stripling',
#  'Charlie Blackmon',
#  'DJ LeMahieu',
#  'Carlos Gonzalez',
#  'Nolan Arenado',
#  'Trevor Story',
#  'David Dahl',
#  'Ian Desmond',
#  'Chris Iannetta',
#  'Tyler Anderson',
#  'Andrew Suarez',
#  'Ivan Nova',
#  'Corey Dickerson',
#  'Starling Marte',
#  'Gregory Polanco',
#  'David Freese',
#  'Francisco Cervelli',
#  'Elias Diaz',
#  'Josh Harrison',
#  'Jordy Mercer',
#  'Ivan Nova',
#  'Andrew McCutchen',
#  'Buster Posey',
#  'Evan Longoria',
#  'Brandon Crawford',
#  'Austin Slater',
#  'Joe Panik',
#  'Steven Duggar',
#  'Gorkys Hernandez',
#  'Andrew Suarez']

# %%
# rq = requests.get('https://legacy.baseballprospectus.com/sortable/index.php?cid=2508773').content
# souped = BeautifulSoup(rq, 'html.parser')
# ttdata = souped.find('table', {'id' : 'TTdata'})
# hdrs = [x.text for x in ttdata.find('tr').findAll('td')]
# data = []
# for r in ttdata.findAll('tr')[1:]:
#     data.append([x.text for x in r.findAll('td')])
    
# pf = pd.DataFrame(data, columns = hdrs)
# numheaders = list(pf)[3:]
# for header in numheaders:
#     pf[header] = pd.to_numeric(pf[header])
# pf = pf[pf['G'] > (pf['G'].mean() - pf["G"].std())]
# pf['WHIP'] = (pf['H'] + pf['BB'] + pf['HBP']) / pf['IP']
# # pf.dtypes
# pf['MULT'] = pf['WHIP'] / pf['WHIP'].mean()
# pf.sort_values('MULT', ascending=False)
# pf
# pf['G'].describe()

make
# Out:
#      AvgPointsPerGame                      Game Info        ID      MULT  \
# 0               25.28  NYM@MIA 08/11/2018 07:10PM ET  11057780  1.199102
# 1               17.89  LAD@COL 08/11/2018 08:10PM ET  11057781  0.952605
# 2               19.88  MIL@ATL 08/11/2018 07:10PM ET  11057787  1.011061
# 3               18.85  CLE@CWS 08/11/2018 07:10PM ET  11057795  1.103888
# 4               17.33   PIT@SF 08/11/2018 09:05PM ET  11057796  0.973450
# 5               15.19  OAK@LAA 08/11/2018 09:07PM ET  11057797  0.977729
# 6               16.26   STL@KC 08/11/2018 07:15PM ET  11057799  1.215483
# 7               17.04  OAK@LAA 08/11/2018 09:07PM ET  11057802  0.936561
# 8               16.68  SEA@HOU 08/11/2018 07:10PM ET  11057810  0.909748
# 9                5.72   STL@KC 08/11/2018 07:15PM ET  11057878       NaN
# 10              10.93  NYM@MIA 08/11/2018 07:10PM ET  11057888  1.131976
# 11              11.71  CLE@CWS 08/11/2018 07:10PM ET  11057895  0.875722
# 12              10.52   PHI@SD 08/11/2018 08:40PM ET  11057905  1.029784
# 0               11.05  CLE@CWS 08/11/2018 07:10PM ET  11057192  0.948192
# 1               11.45  CLE@CWS 08/11/2018 07:10PM ET  11057193  0.948192
# 2                9.28  LAD@COL 08/11/2018 08:10PM ET  11057210       NaN
# 3                9.58   STL@KC 08/11/2018 07:15PM ET  11057199  0.948119
# 4                8.09  LAD@COL 08/11/2018 08:10PM ET  11057202       NaN
# 5                7.76  LAD@COL 08/11/2018 08:10PM ET  11057212       NaN
# 97              NaN         Freddy Galvis         Freddy Galvis (11057502)
# 98      Pablo Lopez          Amed Rosario          Amed Rosario (11057514)
# 99   Mike Clevinger        Yolmer Sanchez        Yolmer Sanchez (11057538)
# 100             NaN            Ryon Healy            Ryon Healy (11057549)
# 101             NaN           Jose Pirela           Jose Pirela (11057534)
# 102             NaN          Martin Prado          Martin Prado (11057529)
# 103  Mike Clevinger          Omar Narvaez          Omar Narvaez (11057568)
# 104             NaN        Cameron Maybin        Cameron Maybin (11057563)
# 105   Andrew Heaney       Jonathan Lucroy       Jonathan Lucroy (11057564)
# 106             NaN        Isaac Galloway        Isaac Galloway (11057560)
# 107             NaN         Bryan Holaday         Bryan Holaday (11057607)
# 108             NaN         Yadiel Rivera         Yadiel Rivera (11057610)
# 109  Mike Clevinger            Adam Engel            Adam Engel (11057654)
# 110   Miles Mikolas       Alcides Escobar       Alcides Escobar (11057627)
# 111             NaN     Guillermo Heredia     Guillermo Heredia (11057679)
#
#          OppPitcher OpposingTeam       PPK Position Roster Position  Salary  \
# 0       Pablo Lopez          MIA  1.959690       SP               P   12900
# 1               NaN          COL  1.397656       SP               P   12800
# 2               NaN          MIL  1.875472       SP               P   10600
# 3    Reynaldo Lopez          CWS  1.984211       SP               P    9500
# 4               NaN          PIT  1.863441       SP               P    9300
# 5     Andrew Heaney          LAA  1.651087       SP               P    9200
# 6       Brad Keller           KC  1.806667       SP               P    9000
# 7       Sean Manaea          OAK  1.936364       SP               P    8800
# 8               NaN          HOU  1.985714       SP               P    8400
# 9     Miles Mikolas          STL  0.953333       SP               P    6000
# 10     Jacob deGrom          NYM  1.884483       SP               P    5800
# 11   Mike Clevinger          CLE  2.129091       SP               P    5500
# 12              NaN          PHI  2.062745       SP               P    5100
# 0    Reynaldo Lopez          CWS  1.905172       SS              SS    5800
# 1    Reynaldo Lopez          CWS  1.974138       3B              3B    5800
# 2               NaN          COL  1.784615       SS              SS    5200
# 3       Brad Keller           KC  1.842308    1B/3B           1B/3B    5200
# 4               NaN          COL  1.586275       2B              2B    5100
# 5               NaN          COL  1.521569    1B/OF           1B/OF    5100
# 6      Jacob deGrom          NYM  1.076471       RP               P    5100
# 7       Pablo Lopez          MIA  1.508163       OF              OF    4900
# 8     Andrew Heaney          LAA  1.989362       OF              OF    4700
# 9               NaN          MIL  2.032609       1B              1B    4600
# 10   Reynaldo Lopez          CWS  1.852174       OF              OF    4600
# 11              NaN          COL  1.600000       OF              OF    4600
# 12              NaN          MIL  2.013333       2B              2B    4500
# 13              NaN          COL  1.686667    OF/SS           SS/OF    4500
# 14              NaN          MIL  2.009302       OF              OF    4300
# 15      Sean Manaea          OAK  1.862791       OF              OF    4300
# 16              NaN          PHI  2.030233       OF              OF    4300
# ..              ...          ...       ...      ...             ...     ...
# 82              NaN          HOU  2.090909       3B              3B    3300
# 83              NaN          PHI  1.924242       3B              3B    3300
# 84              NaN          PHI  1.812121       OF              OF    3300
# 85              NaN          MIL  1.940625       SS              SS    3200
# 86   Mike Clevinger          CLE  2.300000       SS              SS    3200
# 87              NaN          COL  0.962500        C               C    3200
# 88    Miles Mikolas          STL  1.768750       OF              OF    3200
# 89      Sean Manaea          OAK  1.034375    1B/3B           1B/3B    3200
# 90      Sean Manaea          OAK  1.581250    2B/3B           2B/3B    3200
# 91   Mike Clevinger          CLE  1.687097       OF              OF    3100
# 92              NaN          HOU  1.925806        C               C    3100
# 93      Brad Keller           KC  1.525806       2B              2B    3100
# 94              NaN          PIT  1.645161    2B/3B           2B/3B    3100
# 95    Miles Mikolas          STL  1.583333       OF              OF    3000
# 96      Sean Manaea          OAK  1.406667        C               C    3000
# 97              NaN          PHI  1.893333       SS              SS    3000
# 98      Pablo Lopez          MIA  1.816667       SS              SS    3000
# 99   Mike Clevinger          CLE  2.265517       3B              3B    2900
# 100             NaN          HOU  2.310345       1B              1B    2900
# 101             NaN          PHI  1.831034    2B/OF           2B/OF    2900
# 102    Jacob deGrom          NYM  1.568966       3B              3B    2900
# 103  Mike Clevinger          CLE  1.878571        C               C    2800
# 104             NaN          HOU  1.582143       OF              OF    2800
# 105   Andrew Heaney          LAA  1.882143        C               C    2800
# 106    Jacob deGrom          NYM  0.596429       OF              OF    2800
# 107    Jacob deGrom          NYM  1.018519        C               C    2700
# 108    Jacob deGrom          NYM  0.685185    3B/SS           3B/SS    2700
# 109  Mike Clevinger          CLE  1.684615       OF              OF    2600
# 110   Miles Mikolas          STL  1.746154       SS              SS    2600
# 111             NaN          HOU  1.464000       OF              OF    2500
#
#     Team TeamAbbrev  index   Adjusted
# 0    MIA        NYM  131.0  30.313287
# 1    COL        LAD    NaN  17.042108
# 2    MIL        ATL    NaN  20.099885
# 3    CWS        CLE  139.0  20.808280
# 4    PIT         SF    NaN  16.869889
# 5    LAA        OAK   28.0  14.851703
# 6     KC        STL  114.0  19.763749
# 7    OAK        LAA   23.0  15.959006
# 8    HOU        SEA    NaN  15.174593
# 9    NaN         KC   24.0        NaN
# 10   NYM        MIA    1.0  12.372500
# 11   CLE        CWS   19.0  10.254702
# 12   PHI         SD    NaN  10.833327
# 0    NaN        CLE  139.0  10.477525
# 1    NaN        CLE  139.0  10.856802
# 2    NaN        LAD    NaN        NaN
# 3    NaN        STL  114.0   9.082982
# 4    NaN        LAD    NaN        NaN
# 5    NaN        LAD    NaN        NaN
# 6    NaN        MIA    1.0        NaN
# 7    NaN        NYM  131.0   5.862818
# 8    NaN        OAK   28.0   7.735881
# 9    NaN        ATL    NaN        NaN
# 10   NaN        CLE  139.0   8.078599
# 11   NaN        LAD    NaN        NaN
# 12   NaN        ATL    NaN        NaN
# 13   NaN        LAD    NaN        NaN
# 14   NaN        ATL    NaN        NaN
# 15   NaN        LAA   23.0   5.971303
# 16   NaN         SD    NaN        NaN
# ..   ...        ...    ...        ...
# 82   NaN        SEA    NaN        NaN
# 83   NaN         SD    NaN        NaN
# 84   NaN         SD    NaN        NaN
# 85   NaN        ATL    NaN        NaN
# 86   NaN        CWS   19.0   6.063211
# 87   NaN        LAD    NaN        NaN
# 88   NaN         KC   24.0   4.210651
# 89   NaN        LAA   23.0   2.467542
# 90   NaN        LAA   23.0   3.772134
# 91   NaN        CWS   19.0   4.308505
# 92   NaN        SEA    NaN        NaN
# 93   NaN        STL  114.0   4.484604
# 94   NaN         SF    NaN        NaN
# 95   NaN         KC   24.0   3.533673
# 96   NaN        LAA   23.0   3.145930
# 97   NaN         SD    NaN        NaN
# 98   NaN        NYM  131.0   4.323729
# 99   NaN        CWS   19.0   5.412405
# 100  NaN        SEA    NaN        NaN
# 101  NaN         SD    NaN        NaN
# 102  NaN        MIA    1.0        NaN
# 103  NaN        CWS   19.0   4.333219
# 104  NaN        SEA    NaN        NaN
# 105  NaN        OAK   28.0   4.360224
# 106  NaN        MIA    1.0        NaN
# 107  NaN        MIA    1.0        NaN
# 108  NaN        MIA    1.0        NaN
# 109  NaN        CWS   19.0   3.608270
# 110  NaN         KC   24.0   3.377448
# 111  NaN        SEA    NaN        NaN
#
# [125 rows x 17 columns]

# %%
df.head()
# Out:
#   Position                Name + ID          Name        ID Roster Position  \
# 0       SP  Max Scherzer (11036841)  Max Scherzer  11036841               P
# 1       SP    Chris Sale (11037695)    Chris Sale  11037695               P
# 2       SP  James Paxton (11037696)  James Paxton  11037696               P
# 3       SP    Aaron Nola (11037698)    Aaron Nola  11037698               P
# 4       SP  Jacob deGrom (11037697)  Jacob deGrom  11037697               P
#
#    Salary                      Game Info TeamAbbrev  AvgPointsPerGame  \
# 0   13900  ATL@WAS 08/07/2018 07:05PM ET        WAS             26.57
# 1   13500  BOS@TOR 08/07/2018 07:07PM ET        BOS             28.68
# 2   12900  SEA@TEX 08/07/2018 08:05PM ET        SEA             22.67
# 3   12400  PHI@ARI 08/07/2018 09:40PM ET        PHI             21.78
# 4   12400  CIN@NYM 08/07/2018 07:10PM ET        NYM             24.87
#
#   OpposingTeam
# 0          ATL
# 1          TOR
# 2          TEX
# 3          ARI
# 4          CIN

# %%
df.head()
# Out:
#   Position                Name + ID          Name        ID Roster Position  \
# 0       SP  Max Scherzer (11036841)  Max Scherzer  11036841               P
# 1       SP    Chris Sale (11037695)    Chris Sale  11037695               P
# 2       SP  James Paxton (11037696)  James Paxton  11037696               P
# 3       SP    Aaron Nola (11037698)    Aaron Nola  11037698               P
# 4       SP  Jacob deGrom (11037697)  Jacob deGrom  11037697               P
#
#    Salary                      Game Info TeamAbbrev  AvgPointsPerGame
# 0   13900  ATL@WAS 08/07/2018 07:05PM ET        WAS             26.57
# 1   13500  BOS@TOR 08/07/2018 07:07PM ET        BOS             28.68
# 2   12900  SEA@TEX 08/07/2018 08:05PM ET        SEA             22.67
# 3   12400  PHI@ARI 08/07/2018 09:40PM ET        PHI             21.78
# 4   12400  CIN@NYM 08/07/2018 07:10PM ET        NYM             24.87

# %%
get_projected_players()
# hm.find('ul').findAll('li', {'class' : 'player'})
# Out:
# ['Kyle Hendricks',
#  'Jeremy Hellickson',
#  'Adam Eaton',
#  'Trea Turner',
#  'Anthony Rendon',
#  'Bryce Harper',
#  'Juan Soto',
#  'Ryan Zimmerman',
#  'Daniel Murphy',
#  'Spencer Kieboom',
#  'Jeremy Hellickson',
#  'Anthony Rizzo',
#  'Javier Baez',
#  'Ben Zobrist',
#  'Jason Heyward',
#  'David Bote',
#  'Kyle Schwarber',
#  'Willson Contreras',
#  'Kyle Hendricks',
#  'Addison Russell',
#  'Masahiro Tanaka',
#  'Mike Minor',
#  'Shin-Soo Choo',
#  'Rougned Odor',
#  'Elvis Andrus',
#  'Adrian Beltre',
#  'Jurickson Profar',
#  'Ronald Guzman',
#  'Willie Calhoun',
#  'Isiah Kiner-Falefa',
#  'Drew Robinson',
#  'Aaron Hicks',
#  'Giancarlo Stanton',
#  'Gleyber Torres',
#  'Didi Gregorius',
#  'Miguel Andujar',
#  'Luke Voit',
#  'Brett Gardner',
#  'Austin Romine',
#  'Shane Robinson',
#  'Dylan Bundy',
#  'Nathan Eovaldi',
#  'Mookie Betts',
#  'Andrew Benintendi',
#  'Mitch Moreland',
#  'J.D. Martinez',
#  'Xander Bogaerts',
#  'Rafael Devers',
#  'Brock Holt',
#  'Daniel Butler',
#  'Jackie Bradley',
#  'Jonathan Villar',
#  'Tim Beckham',
#  'Adam Jones',
#  'Mark Trumbo',
#  'Trey Mancini',
#  'Chris Davis',
#  'Renato Nunez',
#  'Caleb Joseph',
#  'Cedric Mullins',
#  'Marco Estrada',
#  'Blake Snell',
#  'Mallex Smith',
#  'Joey Wendle',
#  'Jakob Bauers',
#  'Ji-Man Choi',
#  'Carlos Gomez',
#  'Kevin Kiermaier',
#  'Brandon Lowe',
#  'Willy Adames',
#  'Michael Perez',
#  'Randal Grichuk',
#  'Devon Travis',
#  'Justin Smoak',
#  'Teoscar Hernandez',
#  'Kendrys Morales',
#  'Aledmys Diaz',
#  'Luke Maile',
#  'Richard Urena',
#  'Kevin Pillar',
#  'Anthony DeSclafani',
#  'Clay Buchholz',
#  'David Peralta',
#  'Paul Goldschmidt',
#  'A.J. Pollock',
#  'Eduardo Escobar',
#  'Steven Souza',
#  'Ketel Marte',
#  'Nick Ahmed',
#  'Alex Avila',
#  'Clay Buchholz',
#  'Jose Peraza',
#  'Joey Votto',
#  'Eugenio Suarez',
#  'Scooter Gennett',
#  'Phillip Ervin',
#  'Mason Williams',
#  'Tucker Barnhart',
#  'Anthony DeSclafani',
#  'Billy Hamilton',
#  'Jordan Zimmermann',
#  'Ervin Santana',
#  'Joe Mauer',
#  'Eddie Rosario',
#  'Jorge Polanco',
#  'Logan Forsythe',
#  'Max Kepler',
#  'Mitch Garver',
#  'Logan Morrison',
#  'Jake Cave',
#  'Ehire Adrianza',
#  'Michael Gerber',
#  'Jose Iglesias',
#  'Nick Castellanos',
#  'Jeimer Candelario',
#  'Victor Martinez',
#  'Niko Goodrum',
#  'Jim Adduci',
#  'James McCann',
#  'JaCoby Jones',
#  'Jose Urena',
#  'Zack Wheeler',
#  'Amed Rosario',
#  'Jeff McNeil',
#  'Wilmer Flores',
#  'Michael Conforto',
#  'Brandon Nimmo',
#  'Todd Frazier',
#  'Austin Jackson',
#  'Kevin Plawecki',
#  'Zack Wheeler',
#  'Magneuris Sierra',
#  'Brian Anderson',
#  'J.T. Realmuto',
#  'Derek Dietrich',
#  'Starlin Castro',
#  'Martin Prado',
#  'Rafael Ortega',
#  'Miguel Rojas',
#  'Jose Urena',
#  'Kevin Gausman',
#  'Freddy Peralta',
#  'Christian Yelich',
#  'Lorenzo Cain',
#  'Mike Moustakas',
#  'Jesus Aguilar',
#  'Travis Shaw',
#  'Jonathan Schoop',
#  'Eric Thames',
#  'Manny Pina',
#  'Freddy Peralta',
#  'Ronald Acuna',
#  'Ozzie Albies',
#  'Freddie Freeman',
#  'Nick Markakis',
#  'Johan Camargo',
#  'Ender Inciarte',
#  'Tyler Flowers',
#  'Dansby Swanson',
#  'Kevin Gausman',
#  'Gerrit Cole',
#  'Mike Leake',
#  'Mitch Haniger',
#  'Denard Span',
#  'Jean Segura',
#  'Nelson Cruz',
#  'Kyle Seager',
#  'Mike Zunino',
#  'Ryon Healy',
#  'Cameron Maybin',
#  'Dee Gordon',
#  'Tony Kemp',
#  'Alex Bregman',
#  'Carlos Correa',
#  'Josh Reddick',
#  'Yulieski Gurriel',
#  'Marwin Gonzalez',
#  'Tyler White',
#  'Martin Maldonado',
#  'Jake Marisnick',
#  'Carlos Rodon',
#  'Shane Bieber',
#  'Francisco Lindor',
#  'Michael Brantley',
#  'Jose Ramirez',
#  'Edwin Encarnacion',
#  'Brandon Guyer',
#  'Yonder Alonso',
#  'Yan Gomes',
#  'Jason Kipnis',
#  'Rajai Davis',
#  'Nicky Delmonico',
#  'Yolmer Sanchez',
#  'Jose Abreu',
#  'Daniel Palka',
#  'Avisail Garcia',
#  'Omar Narvaez',
#  'Tim Anderson',
#  'Yoan Moncada',
#  'Ryan LaMarre',
#  'Burch Smith',
#  'Austin Gomber',
#  'Matt Carpenter',
#  'Yadier Molina',
#  'Jose Martinez',
#  'Marcell Ozuna',
#  'Paul DeJong',
#  'Jedd Gyorko',
#  'Kolten Wong',
#  'Yairo Munoz',
#  'Harrison Bader',
#  'Whit Merrifield',
#  'Rosell Herrera',
#  'Salvador Perez',
#  'Hunter Dozier',
#  'Lucas Duda',
#  'Jorge Bonifacio',
#  'Brett Phillips',
#  'Adalberto Mondesi',
#  "Ryan O'Hearn",
#  'Jon Gray',
#  'Kenta Maeda',
#  'Joc Pederson',
#  'Justin Turner',
#  'Yasmani Grandal',
#  'Brian Dozier',
#  'Cody Bellinger',
#  'Chris Taylor',
#  'Max Muncy',
#  'Yasiel Puig',
#  'Kenta Maeda',
#  'Charlie Blackmon',
#  'DJ LeMahieu',
#  'Carlos Gonzalez',
#  'Nolan Arenado',
#  'Trevor Story',
#  'David Dahl',
#  'Ian Desmond',
#  'Chris Iannetta',
#  'Jon Gray',
#  'Felix Pena',
#  'Brett Anderson',
#  'Nick Martini',
#  'Matt Chapman',
#  'Jed Lowrie',
#  'Khris Davis',
#  'Matt Olson',
#  'Stephen Piscotty',
#  'Jonathan Lucroy',
#  'Marcus Semien',
#  'Ramon Laureano',
#  'David Fletcher',
#  'Kole Calhoun',
#  'Justin Upton',
#  'Albert Pujols',
#  'Shohei Ohtani',
#  'Andrelton Simmons',
#  'Jose Briceno',
#  'Kaleb Cowart',
#  'Eric Young',
#  'Jacob Nix',
#  'Zach Eflin',
#  'Cesar Hernandez',
#  'Rhys Hoskins',
#  'Nick Williams',
#  'Carlos Santana',
#  'Asdrubal Cabrera',
#  'Odubel Herrera',
#  'Maikel Franco',
#  'Jorge Alfaro',
#  'Zach Eflin',
#  'Manuel Margot',
#  'Eric Hosmer',
#  'Hunter Renfroe',
#  'Franmil Reyes',
#  'Christian Villanueva',
#  'Austin Hedges',
#  'Freddy Galvis',
#  'Cory Spangenberg',
#  'Jacob Nix',
#  'Derek Holland',
#  'Clay Holmes',
#  'Corey Dickerson',
#  'Starling Marte',
#  'Gregory Polanco',
#  'David Freese',
#  'Francisco Cervelli',
#  'Josh Bell',
#  'Josh Harrison',
#  'Jordy Mercer',
#  'Clay Holmes',
#  'Andrew McCutchen',
#  'Buster Posey',
#  'Evan Longoria',
#  'Brandon Crawford',
#  'Austin Slater',
#  'Joe Panik',
#  'Steven Duggar',
#  'Gorkys Hernandez',
#  'Derek Holland']

# %%
# df = prep_dataframe()

# pd.merge([df, df[df['Position'] == 'SP']['N']]how='left')
# Out:
#     Position                     Name + ID               Name        ID  \
# 0         SP        Gerrit Cole (11047795)        Gerrit Cole  11047795
# 1         SP        Blake Snell (11047418)        Blake Snell  11047418
# 2         SP    Masahiro Tanaka (11047798)    Masahiro Tanaka  11047798
# 3         SP           Jon Gray (11047804)           Jon Gray  11047804
# 4         SP        Kenta Maeda (11047812)        Kenta Maeda  11047812
# 5         SP     Nathan Eovaldi (11047816)     Nathan Eovaldi  11047816
# 6         SP        Dylan Bundy (11047817)        Dylan Bundy  11047817
# 7         SP         Mike Minor (11047824)         Mike Minor  11047824
# 8         SP      Derek Holland (11047836)      Derek Holland  11047836
# 9         OF       Mookie Betts (11047429)       Mookie Betts  11047429
# 10        SP         Mike Leake (11047851)         Mike Leake  11047851
# 11        OF      J.D. Martinez (11047430)      J.D. Martinez  11047430
# 12        2B       Brian Dozier (11047431)       Brian Dozier  11047431
# 13        SP      Marco Estrada (11047856)      Marco Estrada  11047856
# 14        3B      Nolan Arenado (11047433)      Nolan Arenado  11047433
# 15        OF   Charlie Blackmon (11047436)   Charlie Blackmon  11047436
# 16        OF         David Dahl (11047434)         David Dahl  11047434
# 17        OF        Yasiel Puig (11047435)        Yasiel Puig  11047435
# 18        OF    Carlos Gonzalez (11047437)    Carlos Gonzalez  11047437
# 19         C    Yasmani Grandal (11047438)    Yasmani Grandal  11047438
# 20        SS       Trevor Story (11047439)       Trevor Story  11047439
# 21        OF  Giancarlo Stanton (11047441)  Giancarlo Stanton  11047441
# 22     1B/3B          Max Muncy (11047443)          Max Muncy  11047443
# 23        OF       Joc Pederson (11047445)       Joc Pederson  11047445
# 24     1B/OF     Cody Bellinger (11047446)     Cody Bellinger  11047446
# 25        SS     Didi Gregorius (11047442)     Didi Gregorius  11047442
# 26        OF        Aaron Hicks (11047449)        Aaron Hicks  11047449
# 106              OF    2900   BAL@TB 08/09/2018 07:10PM ET         TB
# 107               C    2800  BOS@TOR 08/09/2018 07:07PM ET        TOR
# 108              OF    2800  SEA@HOU 08/09/2018 08:10PM ET        SEA
# 109              OF    2800  TEX@NYY 08/09/2018 07:05PM ET        NYY
# 110               C    2700   BAL@TB 08/09/2018 07:10PM ET        BAL
# 111               C    2700  SEA@HOU 08/09/2018 08:10PM ET        HOU
#
#      AvgPointsPerGame OpposingTeam       PPK  index       OppPitcher
# 0               26.16          SEA  2.076190     67       Mike Leake
# 1               21.76          BAL  1.892174     29      Dylan Bundy
# 2               18.65          TEX  1.810680     38       Mike Minor
# 3               17.80          LAD  2.022727     24      Kenta Maeda
# 4               15.52          COL  1.869880     17         Jon Gray
# 5               16.38          TOR  2.127273     74    Marco Estrada
# 6               16.58           TB  2.181579      5      Blake Snell
# 7               13.75          NYY  1.936620      8  Masahiro Tanaka
# 8               12.83          PIT  2.004688    338      Clay Holmes
# 9               12.33          TOR  2.089831     74    Marco Estrada
# 10              12.10          HOU  2.122807      2      Gerrit Cole
# 11              11.06          TOR  1.975000     74    Marco Estrada
# 12               7.99          COL  1.452727     17         Jon Gray
# 13              11.22          BOS  2.077778     28   Nathan Eovaldi
# 14               9.96          LAD  1.844444     24      Kenta Maeda
# 15               8.82          LAD  1.633333     24      Kenta Maeda
# 16               6.03          LAD  1.137736     24      Kenta Maeda
# 17               7.39          COL  1.394340     17         Jon Gray
# 18               7.58          LAD  1.457692     24      Kenta Maeda
# 19               7.69          COL  1.478846     17         Jon Gray
# 20               9.33          LAD  1.829412     24      Kenta Maeda
# 21               9.03          TEX  1.770588     38       Mike Minor
# 22               8.08          COL  1.616000     17         Jon Gray
# 23               6.18          COL  1.261224     17         Jon Gray
# 24               7.62          COL  1.555102     17         Jon Gray
# 25               8.74          TEX  1.783673     38       Mike Minor
# 26               8.52          TEX  1.775000     38       Mike Minor
# 27              10.06          TOR  2.140426     74    Marco Estrada
# 28               6.82          BAL  1.451064     29      Dylan Bundy
# 29               6.56          COL  1.395745     17         Jon Gray
# ..                ...          ...       ...    ...              ...
# 82               3.94          NYY  1.094444      8  Masahiro Tanaka
# 83               5.81          BOS  1.660000     28   Nathan Eovaldi
# 84               5.73           TB  1.637143      5      Blake Snell
# 85               4.67           TB  1.334286      5      Blake Snell
# 86               6.12          SEA  1.748571     67       Mike Leake
# 87               6.08          TEX  1.737143     38       Mike Minor
# 88               6.12          BOS  1.800000     28   Nathan Eovaldi
# 89               6.82           TB  2.005882      5      Blake Snell
# 90               6.12           TB  1.800000      5      Blake Snell
# 91               6.99          HOU  2.055882      2      Gerrit Cole
# 92               5.91           SF  1.738235     49    Derek Holland
# 93               6.12           TB  1.854545      5      Blake Snell
# 94               6.89          HOU  2.087879      2      Gerrit Cole
# 95               5.94          NYY  1.800000      8  Masahiro Tanaka
# 96               5.38          TOR  1.681250     74    Marco Estrada
# 97               6.77          HOU  2.115625      2      Gerrit Cole
# 98               5.10          LAD  1.645161     24      Kenta Maeda
# 99               5.34          PIT  1.722581    338      Clay Holmes
# 100              4.44          BAL  1.480000     29      Dylan Bundy
# 101              5.24           TB  1.746667      5      Blake Snell
# 102              0.00           TB  0.000000      5      Blake Snell
# 103              6.05          HOU  2.016667      2      Gerrit Cole
# 104              0.00          TOR  0.000000     74    Marco Estrada
# 105              2.91          BOS  1.003448     28   Nathan Eovaldi
# 106              2.00          BAL  0.689655     29      Dylan Bundy
# 107              5.67          BOS  2.025000     28   Nathan Eovaldi
# 108              4.38          HOU  1.564286      2      Gerrit Cole
# 109              4.00          TEX  1.428571     38       Mike Minor
# 110              4.89           TB  1.811111      5      Blake Snell
# 111              5.07          SEA  1.877778     67       Mike Leake
#
# [112 rows x 13 columns]

# %%
rq = requests.get('https://www.teamrankings.com/mlb/stat/runs-per-game').content
souped = BeautifulSoup(rq, 'html.parser')
table = souped.find('table', {'class' : 'tr-table datatable scrollable'})
rows = table.findAll('tr')
header = [x.text for x in rows[0].findAll('th')]
content = []
for row in rows[1:]:
    content.append([x.text for x in row.findAll('td')])
    
tmdf = pd.DataFrame(content, columns = header)
tmdf ['Team'] = [team_dict[x] for x in tmdf.Team]
tmdf['2018'] = pd.to_numeric(tmdf['2018'])
tmdf['MOD'] = tmdf['2018'].mean() / tmdf['2018']
tmdf[['Team', 'MOD']]
# tmdf.iloc[:, 1:3]
# souped
# Out:
#     Team       MOD
# 0    BOS  0.826407
# 1    NYY  0.861573
# 2    CLE  0.871689
# 3    HOU  0.898051
# 4    CHC  0.898051
# 5    TEX  0.929923
# 6    ATL  0.935784
# 7    LAD  0.937754
# 8    OAK  0.943715
# 9    COL  0.949751
# 10   WSH  0.972562
# 11   LAA  0.972562
# 12   CIN  0.974690
# 13   TOR  0.978974
# 14   PIT  0.981131
# 15   ARI  0.992056
# 16  STL   1.000974
# 17   MIN  1.007768
# 18   MIL  1.007768
# 19   PHI  1.019298
# 20    TB  1.058036
# 21   SEA  1.060556
# 22   CWS  1.099835
# 23    SF  1.110806
# 24   NYM  1.136310
# 25   BAL  1.139216
# 26    SD  1.153972
# 27   DET  1.184663
# 28   MIA  1.194191
# 29    KC  1.200629

# %%
ddf = prep_dataframe()
ddf
# ddf.MULT_y.unique()
# ddf[['OpposingTeam', 'MULT_y']]

# ddf[ddf['OpposingTeam'] == 'NYY']
# Out:
#     AvgPointsPerGame                      Game Info        ID    MULT_y  \
# 0              26.16  SEA@HOU 08/09/2018 08:10PM ET  11047795  1.060556
# 1              21.76   BAL@TB 08/09/2018 07:10PM ET  11047418  1.139216
# 2              18.65  TEX@NYY 08/09/2018 07:05PM ET  11047798  0.929923
# 3              17.80  LAD@COL 08/09/2018 08:40PM ET  11047804  0.937754
# 4              15.52  LAD@COL 08/09/2018 08:40PM ET  11047812  0.949751
# 5              16.38  BOS@TOR 08/09/2018 07:07PM ET  11047816  0.978974
# 6              16.58   BAL@TB 08/09/2018 07:10PM ET  11047817  1.058036
# 7              13.75  TEX@NYY 08/09/2018 07:05PM ET  11047824  0.861573
# 8              12.83   PIT@SF 08/09/2018 10:15PM ET  11047836  0.981131
# 6          Jon Gray          COL  1.394340       OF              OF    5300
# 7       Kenta Maeda          LAD  1.457692       OF              OF    5200
# 8          Jon Gray          COL  1.478846        C               C    5200
# 9       Kenta Maeda          LAD  1.829412       SS              SS    5100
# 10       Mike Minor          TEX  1.770588       OF              OF    5100
# 11         Jon Gray          COL  1.616000    1B/3B           1B/3B    5000
# 12         Jon Gray          COL  1.261224       OF              OF    4900
# 13         Jon Gray          COL  1.555102    1B/OF           1B/OF    4900
# 14       Mike Minor          TEX  1.783673       SS              SS    4900
# 15       Mike Minor          TEX  1.775000       OF              OF    4800
# 16    Marco Estrada          TOR  2.140426       OF              OF    4700
# 17      Dylan Bundy          BAL  1.451064       OF              OF    4700
# ..              ...          ...       ...      ...             ...     ...
# 70  Masahiro Tanaka          NYY  1.094444    2B/OF           2B/OF    3600
# 71   Nathan Eovaldi          BOS  1.660000       2B              2B    3500
# 72      Blake Snell           TB  1.637143       2B              2B    3500
# 73      Blake Snell           TB  1.334286       3B              3B    3500
# 74       Mike Leake          SEA  1.748571       OF              OF    3500
# 75       Mike Minor          TEX  1.737143        C               C    3500
# 76   Nathan Eovaldi          BOS  1.800000       1B              1B    3400
# 77      Blake Snell           TB  2.005882       OF              OF    3400
# 78      Blake Snell           TB  1.800000    1B/OF           1B/OF    3400
# 79      Gerrit Cole          HOU  2.055882    2B/OF           2B/OF    3400
# 80    Derek Holland           SF  1.738235       SS              SS    3400
# 81      Blake Snell           TB  1.854545    3B/SS           3B/SS    3300
# 82      Gerrit Cole          HOU  2.087879       3B              3B    3300
# 83  Masahiro Tanaka          NYY  1.800000       1B              1B    3300
# 84    Marco Estrada          TOR  1.681250    2B/SS           2B/SS    3200
# 85      Gerrit Cole          HOU  2.115625       1B              1B    3200
# 86      Kenta Maeda          LAD  1.645161        C               C    3100
# 87      Clay Holmes          PIT  1.722581       2B              2B    3100
# 88      Dylan Bundy          BAL  1.480000        C               C    3000
# 89      Blake Snell           TB  1.746667       1B              1B    3000
# 90      Blake Snell           TB  0.000000       OF              OF    3000
# 91      Gerrit Cole          HOU  2.016667        C               C    3000
# 92    Marco Estrada          TOR  0.000000        C               C    2900
# 93   Nathan Eovaldi          BOS  1.003448       SS              SS    2900
# 94      Dylan Bundy          BAL  0.689655       OF              OF    2900
# 95   Nathan Eovaldi          BOS  2.025000        C               C    2800
# 96      Gerrit Cole          HOU  1.564286       OF              OF    2800
# 97       Mike Minor          TEX  1.428571       OF              OF    2800
# 98      Blake Snell           TB  1.811111        C               C    2700
# 99       Mike Leake          SEA  1.877778        C               C    2700
#
#    Team TeamAbbrev  index   Adjusted
# 0   SEA        HOU     67  27.744133
# 1   BAL         TB     29  24.789333
# 2   TEX        NYY     38  17.343072
# 3   LAD        COL     24  16.692028
# 4   COL        LAD     17  14.740139
# 5   TOR        BOS     74  16.035600
# 6    TB        BAL      5  17.542244
# 7   NYY        TEX      8  11.846631
# 8   PIT         SF    338  12.587907
# 9   HOU        SEA      2  10.866418
# 10  BOS        TOR     28   9.272286
# 11   SF        PIT     49   8.431020
# 0   NaN        BOS     74  10.827736
# 1   NaN        BOS     74   9.712470
# 2   NaN        LAD     17   7.200962
# 3   NaN        COL     24   8.756823
# 4   NaN        COL     24   7.754536
# 5   NaN        COL     24   5.301570
# 6   NaN        LAD     17   6.660214
# 7   NaN        COL     24   6.664329
# 8   NaN        LAD     17   6.930588
# 9   NaN        COL     24   8.202927
# 10  NaN        NYY     38   7.493633
# 11  NaN        LAD     17   7.282074
# 12  NaN        LAD     17   5.569705
# 13  NaN        LAD     17   6.867501
# 14  NaN        NYY     38   7.252974
# 15  NaN        NYY     38   7.070405
# 16  NaN        BOS     74   8.834308
# 17  NaN         TB     29   6.128230
# ..  ...        ...    ...        ...
# 70  NaN        TEX      8   3.015582
# 71  NaN        TOR     28   3.595600
# 72  NaN        BAL      5   4.247325
# 73  NaN        BAL      5   3.461607
# 74  NaN        HOU     67   5.575878
# 75  NaN        NYY     38   5.045547
# 76  NaN        TOR     28   3.787447
# 77  NaN        BAL      5   5.055280
# 78  NaN        BAL      5   4.536410
# 79  NaN        SEA      2   4.945659
# 80  NaN        PIT     49   5.171232
# 81  NaN        BAL      5   4.536410
# 82  NaN        SEA      2   4.874905
# 83  NaN        TEX      8   4.546335
# 84  NaN        BOS     74   4.724511
# 85  NaN        SEA      2   4.790001
# 86  NaN        COL     24   4.483915
# 87  NaN         SF    338   5.654629
# 88  NaN         TB     29   3.989639
# 89  NaN        BAL      5   3.884116
# 90  NaN        BAL      5   0.000000
# 91  NaN        SEA      2   4.280577
# 92  NaN        BOS     74   0.000000
# 93  NaN        TOR     28   1.800894
# 94  NaN         TB     29   1.797135
# 95  NaN        TOR     28   3.508959
# 96  NaN        SEA      2   3.098996
# 97  NaN        NYY     38   3.319439
# 98  NaN        BAL      5   3.624680
# 99  NaN        HOU     67   4.619232
#
# [112 rows x 17 columns]

# %%
df.TeamAbbrev.unique()
# Out:
# array(['HOU', 'TB', 'NYY', 'COL', 'LAD', 'BOS', 'BAL', 'TEX', 'SF', 'SEA',
#        'TOR', 'PIT'], dtype=object)

# %%
teams = make_n_teams(1, positions)
export_team(teams)
teams
# Out:
# Extracting csv
# Filtering by projected players
# Expanding dataframe
# Getting pitcher and team score information
# swaps: 5
# swaps: 6
# Avg points (adj): 123.09943840652352
# Avg points: 89.12
# Salary: 50000
# Salary: 47300
# Avg Points: 91.16
# Avg w/o cap: 91.84
# Sal w/o cap: 51400
# ratchet
# [                 AvgPointsPerGame                      Game Info        ID  \
#  Roster Position
#  C                            5.07  OAK@MIN 08/23/2018 08:10PM ET  11121044
#  1B                           7.22  OAK@MIN 08/23/2018 08:10PM ET  11120930
#  2B                           7.92  OAK@MIN 08/23/2018 08:10PM ET  11120916
#  SS                           7.56  OAK@MIN 08/23/2018 08:10PM ET  11120921
#  3B                           8.12  OAK@MIN 08/23/2018 08:10PM ET  11120922
#  OF                           9.66  OAK@MIN 08/23/2018 08:10PM ET  11120913
#  OF                           5.72    KC@TB 08/23/2018 07:10PM ET  11121007
#  OF                           4.46    KC@TB 08/23/2018 07:10PM ET  11121057
#  P                           15.48  ATL@MIA 08/23/2018 07:10PM ET  11120909
#  P                           17.91  OAK@MIN 08/23/2018 08:10PM ET  11120906
#
#                       MULT           NAME             Name  \
#  Roster Position
#  C                1.702875   Kohl Stewart  Jonathan Lucroy
#  1B               1.702875   Kohl Stewart       Matt Olson
#  2B               1.702875   Kohl Stewart       Jed Lowrie
#  SS               1.702875   Kohl Stewart    Marcus Semien
#  3B               1.702875   Kohl Stewart     Matt Chapman
#  OF               1.702875   Kohl Stewart      Khris Davis
#  OF               0.998196    Danny Duffy     Carlos Gomez
#  OF               0.859923  Tyler Glasnow   Rosell Herrera
#  P                1.180548            NaN     Sean Newcomb
#  P                0.989037            NaN    Trevor Cahill
#
#                                    Name + ID     OppPitcher OpposingTeam  \
#  Roster Position
#  C                Jonathan Lucroy (11121044)   Kohl Stewart          MIN
#  1B                    Matt Olson (11120930)   Kohl Stewart          MIN
#  2B                    Jed Lowrie (11120916)   Kohl Stewart          MIN
#  SS                 Marcus Semien (11120921)   Kohl Stewart          MIN
#  3B                  Matt Chapman (11120922)   Kohl Stewart          MIN
#  OF                   Khris Davis (11120913)   Kohl Stewart          MIN
#  OF                  Carlos Gomez (11121007)    Danny Duffy           KC
#  OF                Rosell Herrera (11121057)  Tyler Glasnow           TB
#  P                   Sean Newcomb (11120909)            NaN          MIA
#  P                  Trevor Cahill (11120906)   Kohl Stewart          MIN
#
#                        PPK Position  Salary Team TeamAbbrev  index   Adjusted
#  Roster Position
#  C                1.748276        C    2900  NaN        OAK  135.0   8.633577
#  1B               1.679070       1B    4300  NaN        OAK  135.0  12.294758
#  2B               1.616327       2B    4900  NaN        OAK  135.0  13.486771
#  SS               1.643478       SS    4600  NaN        OAK  135.0  12.873736
#  3B               1.765217       3B    4600  NaN        OAK  135.0  13.827346
#  OF               1.694737       OF    5700  NaN        OAK  135.0  16.449774
#  OF               1.787500       OF    3200  NaN         TB   33.0   5.709682
#  OF               1.592857       OF    2800  NaN         KC    8.0   3.835256
#  P                1.984615       SP    7800  MIA        ATL    NaN  18.274886
#  P                1.946739       SP    9200  MIN        OAK  135.0  17.713653  ]

# %%
# Out:
#           P         P         C        1B        2B        3B        SS  \
# 0  11057169  11057171  11057596  11057549  11057462  11057193  11057472
# 0  11057170  11057172  11057303  11057359  11057448  11057538  11057192
# 0  11057791  11057183  11057287  11057228  11057242  11057349  11057328
#
#          OF        OF        OF
# 0  11057236  11057563  11057654
# 0  11057487  11057507  11057458
# 0  11057319  11057237  11057340

# %%
get_pitcher_adjustments().describe()
# Out:
#              MULT
# count  603.000000
# mean     1.000000
# std      0.293691
# min      0.236190
# 25%      0.832518
# 50%      0.945883
# 75%      1.087365
# max      3.320969

# %%
url = "http://mlb.mlb.com/stats/sortable.jsp#elem=%5Bobject+Object%5D&tab_level=child&\
click_text=Sortable+Player+hitting&game_type='R'&season=2018&season_type=ANY&\
league_code='MLB'&sectionType=sp&statType=hitting&page=1&ts=1535065079547&\
playerType=QUALIFIER&sportCode='mlb'&split=&team_id=&active_sw=&position=&\
page_type=SortablePlayer&sortOrder='desc'&sortColumn=avg&results=&perPage=50&\
timeframe=d1&last_x_days=1&extended=0"

requests.get(url).content
# Out:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\t\t\t\n\t\n\t\n\n\n \t\n\t\t\n\t\t\n\t\n\t\n\n\n\n\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n    \n\n    \n\n    \n    \n    \n    \n    \n    \n\n\n\n\n    \n    \n    \n    \n\n\n\n\n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n    \n    \n    \n\n\n\n\n\n\n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n\n\n\n\n\n    \n    \n\n\n\n\n<!DOCTYPE html>\n\n<!--[if lt IE 7 ]> <html class="ie6 lt-ie9 " lang="en" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]-->\n\n<!--[if IE 7 ]> <html class="ie7 lt-ie9 " lang="en" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]-->\n\n<!--[if IE 8 ]> <html class="ie8 lt-ie9 " lang="en" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]-->\n\n<!--[if IE 9 ]> <html class="ie9 " lang="en" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <![endif]-->\n\n<!--[if (gt IE 9)|!(IE)]><!--> <html class="" lang="en" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->\n\n<!-- stopgap_start -->\n\n\n\n\n    <head>\n        \n\n        \n\n\n<script type="text/javascript">\nwindow.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(14),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,-1!==o.indexOf("dev")&&(s.dev=!0),-1!==o.indexOf("nr_dev")&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,e,n)])}catch(s){try{i("ierr",[s,(new Date).getTime(),!0])}catch(c){}}return"function"==typeof f?f.apply(this,a(arguments)):!1}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t){i("err",[t,(new Date).getTime()])}var i=t("handle"),a=t(15),s=t("ee"),c=t("loader"),f=window.onerror,u=!1,d=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(l){"stack"in l&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),u=!0)}s.on("fn-start",function(t,e,n){u&&(d+=1)}),s.on("fn-err",function(t,e,n){u&&(this.thrown=!0,o(n))}),s.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),s.on("internal-error",function(t){i("ierr",[t,(new Date).getTime(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7);t("loader").features.stn=!0,t(6);var c=NREUM.o.EV;o.on("fn-start",function(t,e){var n=t[0];n instanceof c&&(this.bstStart=Date.now())}),o.on("fn-end",function(t,e){var n=t[0];n instanceof c&&i("bst",[n,e,this.bstStart,Date.now()])}),a.on("fn-start",function(t,e,n){this.bstStart=Date.now(),this.bstType=n}),a.on("fn-end",function(t,e){i("bstTimer",[e,this.bstStart,Date.now(),this.bstType])}),s.on("fn-start",function(){this.bstStart=Date.now()}),s.on("fn-end",function(t,e){i("bstTimer",[e,this.bstStart,Date.now(),"requestAnimationFrame"])}),o.on("pushState-start",functio ...
